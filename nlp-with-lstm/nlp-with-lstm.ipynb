# %% [markdown]
# # NLP con Long-Short Term Memory (LSTM)

# %% [markdown]
# ##### Jean Pierre Londoño González
# ##### Mini-Proyecto de clasificación de texto con LSTM
# ##### 23AGO2025

# %% [markdown]
# En este notebook se implementa un clasificador de titulares de noticias en español utilizando una red neuronal LSTM. Las noticias fueron tomadas de la página de RCN y los titulares se clasificaron en cinco categorías: salud, tecnología, Colombia, economía y deportes. Para la tokenización se emplean las utilidades de la librería Hugging Face Transformers.
#
# #### Referencias
# - Dataset: https://huggingface.co/datasets/Nicky0007/titulos_noticias_rcn_clasificadas

# %% [markdown]
# ### 1. Importación de librerias y carga de modelos

# %% [markdown]
# Inicio importando las librerías necesarias para el procesamiento de lenguaje natural, la manipulación de datos y la construcción del modelo. Esto incluye spaCy y NLTK para análisis lingüístico, stemming y léxicos como WordNet y SentiWordNet; pandas y NumPy para manejo de datos; y PyTorch junto con PyTorch Lightning para definir, entrenar y evaluar el modelo. Finalmente, se incluyen scikit-learn y torchmetrics para calcular métricas de rendimiento como precisión y reportes de clasificación.

# %%
import warnings  # Control y filtrado de mensajes de advertencia
# Desactiva advertencias para mantener limpia la salida
warnings.filterwarnings('ignore')

# Procesamiento de lenguaje natural y utilidades
import numpy as np  # Cálculo numérico y manejo de arreglos multidimensionales
import spacy  # Biblioteca para NLP avanzada (tokenización, POS tagging, dependencias, etc.)
import pandas as pd  # Manipulación y análisis de datos en estructuras tipo DataFrame

import nltk  # Biblioteca general de NLP (tokenización, stemming, stopwords, etc.)
from nltk.corpus import sentiwordnet as swn  # Léxico de sentimientos basado en WordNet
from nltk.corpus import wordnet as wn  # Diccionario semántico de palabras en inglés
from nltk.corpus import stopwords  # Lista de palabras vacías (stopwords) en múltiples idiomas
from nltk.stem.snowball import SpanishStemmer  # Algoritmo de stemming para español

import re  # Expresiones regulares para búsqueda y limpieza de texto
import unicodedata  # Normalización de caracteres Unicode (acentos, tildes, etc.)
from collections import Counter  # Conteo de frecuencias de elementos (tokens, palabras, etc.)

from datasets import load_dataset, concatenate_datasets # Carga y manipulación de datasets de Hugging Face
import os  # Manejo de rutas y operaciones del sistema de archivos

# Deep Learning con PyTorch
import torch  # Librería principal de tensores y operaciones en GPU
import torch.nn as nn  # Definición de capas de redes neuronales
import torch.nn.functional as F  # Funciones de activación y operaciones de redes
from torch.utils.data import Dataset  # Clase base para crear datasets personalizados
from torch.utils.data import random_split  # División aleatoria de datasets en train/test
from torch.utils.data import DataLoader  # Manejo eficiente de lotes (batches) de datos
from torch.utils.data import Subset

# Entrenamiento estructurado con PyTorch Lightning
from pytorch_lightning import LightningModule, Trainer  # Clase base y manejador de entrenamiento
from pytorch_lightning.loggers import TensorBoardLogger  # Registro de métricas en TensorBoard
from pytorch_lightning.callbacks.early_stopping import EarlyStopping  # Detener entrenamiento temprano si no mejora
from torchmetrics import Accuracy  # Métrica de precisión para clasificación

# Tipado para mayor legibilidad y validación
from typing import Tuple, Dict  # Definición de tipos de datos para funciones y estructuras

# Métricas de evaluación con Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report  

import optuna

# %% [markdown]
# ### 2. Cargue de datos

# %% [markdown]
# El dataset contiene titulares de noticias en español organizados por categorías. Está disponible en el Hugging Face Hub, lo que permite descargarlo fácilmente y utilizarlo directamente en entrenamientos o pruebas de modelos de NLP.

# %%
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
dataset = load_dataset("Nicky0007/titulos_noticias_rcn_clasificadas")
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'url'],
#         num_rows: 7224
#     })
#     test: Dataset({
#         features: ['text', 'label', 'url'],
#         num_rows: 1806
#     })
# })

# %% [markdown]
# El dataset incluye tres columnas: el título de la noticia (text), la categoría asociada (label) y el enlace a la publicación original (url). Para entrenar y validar el modelo, se dispone de 7,224 titulares en el conjunto de entrenamiento y 1,806 en el conjunto de prueba.

# %%
tr_dataset = dataset["train"]
te_dataset = dataset["test"]
full_dataset = concatenate_datasets([tr_dataset, te_dataset])

# %% [markdown]
# Observemos uno de sus registros

# %%
full_dataset[0]
# Out:
# {'text': 'Fútbol ¡Sonríe el fútbol! Médicos confirman que la salud de Pelé está mejorando Médicos que atienden al exjugador brasileño en Sao Paulo afirman que su condición de salud está mejorando. ',
#  'label': 'deportes',
#  'url': 'https://www.noticiasrcn.com/deportes/salud-de-pele-esta-mejorando-435134'}

# %%
pd.Series(full_dataset['label']).value_counts()
# Out:
# deportes      1806
# tecnologia    1806
# colombia      1806
# salud         1806
# economia      1806
# Name: count, dtype: int64

# %% [markdown]
# Se valida que el dataset esta balanceado, pues cada categoria tiene 1806 registros.

# %% [markdown]
# Para los efectos de la tarea nos servirá el texto y la categoría.
#
# A manera general, observemos que tan largos o cortos tienden a ser los textos.

# %%
text_lengths = [len(row['text']) for row in full_dataset]
print(f"Texto más corto: {min(text_lengths)}")
print(f"Texto más largo: {max(text_lengths)}")
print(f"Longitud promedio: {sum(text_lengths) / len(text_lengths)}")
# Out:
# Texto más corto: 63
# Texto más largo: 362
# Longitud promedio: 210.4736434108527

# %% [markdown]
# Estos valores son la cantidad de *caractéres* que tiene las secuencias. Una decisión ingenua pero útil en este momento podría ser ajustar la longitud de las secuencias que vamos a usar para el entrenamiento a unos 300 tokens. Esto podría ser suficiente para capturar una porción significativa de los textos.

# %% [markdown]
# ### 3. Definición del Tokenizer

# %% [markdown]
# Ahora, vamos a definir el tokenizer para nuestra tarea. Para mantener las cosas simples, vamos a mantener un conteo de palabras y vamos a hacer un corte hasta los primeros 50mil tokens.

# %%
# Descargar recursos de NLTK
nltk.download("stopwords", quiet=True)

spanish_stopwords = set(stopwords.words("spanish"))
stemmer = SpanishStemmer()

def simple_tokenizer(text, remove_stopwords=True, stemming=True, normalize_accents=True):
    # 1. Minúsculas
    text = text.lower()
    
    # 2. Normalizar acentos
    if normalize_accents:
        text = ''.join(
            c for c in unicodedata.normalize('NFD', text)
            if unicodedata.category(c) != 'Mn'
        )
    
    # 3. Mantener solo letras (a-z, ñ)
    text = re.sub(r"[^a-zñ]+", " ", text)
    
    # 4. Tokenizar por espacios
    tokens = text.strip().split()
    
    # 5. Eliminar stopwords
    if remove_stopwords:
        tokens = [t for t in tokens if t not in spanish_stopwords]
    
    # 6. Stemming
    if stemming:
        tokens = [stemmer.stem(t) for t in tokens]
    
    return tokens

# %%
# Construimos el vocabulario a partir de conjunto de datos.
token_counts = Counter()
for text in full_dataset["text"]:
    token_counts.update(simple_tokenizer(text))

# 50k tokens
top_n_tokens = list(token_counts.keys())[:18640-2]
vocab = {"[PAD]": 0, "[UNK]": 1}
for token in top_n_tokens:
    vocab[token] = len(vocab)

def tokenize_text(text, max_length=50):
    tokens = simple_tokenizer(text)
    ids = [vocab.get(tok, vocab["[UNK]"]) for tok in tokens[:max_length]]
    ids += [vocab["[PAD]"]] * (max_length - len(ids))
    return ids

# %% [markdown]
# Exploremos ahora el tokenizador obtenido.

# %%
print(f"Vocabulario: {len(vocab)} tokens")
print("Primeros 15 tokens:")
print(f"{top_n_tokens[:15]}")
print("15 tokens de en medio:")
print(f"{top_n_tokens[1000:1015]}")
print("Últimos 15 tokens:")
print(f"{top_n_tokens[-15:]}")
# Out:
# Vocabulario: 9890 tokens
# Primeros 15 tokens:
# ['futbol', 'sonri', 'medic', 'confirm', 'salud', 'pel', 'mejor', 'atiend', 'exjug', 'brasilen', 'sao', 'paul', 'afirm', 'condicion', 'especial']
# 15 tokens de en medio:
# ['competidor', 'pronost', 'crecimient', 'decret', 'desastr', 'ola', 'invernal', 'territori', 'viruel', 'mon', 'juli', 'institut', 'ins', 'dio', 'dias']
# Últimos 15 tokens:
# ['oyent', 'acrobaci', 'nortemaerican', 'stress', 'comprometeri', 'samb', 'suramerican', 'resolu', 'circular', 'agorafobi', 'playback', 'fuel', 'albirroj', 'parpade', 'evoc']

# %% [markdown]
# Esta forma de exploración es para darnos una idea de las palabras más utilizadas en el corpus y nos dará un indicio de si la tokenización es adecuada o no. Vemos que tenemos algunos stop words, como artículos (el, la) y conectores (del, que). Para una tarea de clasificación de texto podríamos prescindir de estos pero para facilitar las cosas y ya que los demás tokens lucen bien, podemos preservarlos.

# %% [markdown]
# Lo que obtenemos son los ids de cada token según el vocabulario. Algo clave aquí es el padding: durante el entrenamiento necesito que todas las secuencias tengan la misma longitud para trabajar con matrices de forma cómoda. Como los textos no siempre tienen el mismo tamaño, si una secuencia es más larga la recorto, y si es más corta, la relleno con un token especial de padding. En este caso, definí que todas las cadenas tengan 8 tokens, por lo que las más cortas se completan hasta llegar a ese número.

# %% [markdown]
# ### 4. Definición del dataset de pytorch

# %% [markdown]
# Ahora podemos proceder a definir el dataset.

# %%
class SpanishNewsDataset(Dataset):

    def __init__(self, tokenizer, dataset, seq_length: int = 512):
        self.tokenizer = tokenizer
        self.dataset = dataset
        self.seq_length = seq_length
        self.id_2_class_map = dict(enumerate(np.unique(dataset[:]['label'])))
        self.class_2_id_map = {v: k for k, v in self.id_2_class_map.items()}
        self.num_classes = len(self.id_2_class_map)
    
    def __getitem__(self, index) -> Dict[str, torch.Tensor]:
        text, y = self.dataset[index]['text'], self.dataset[index]['label']
        y = self.class_2_id_map[y]
        data = {'input_ids': torch.tensor(self.tokenizer(text, max_length=self.seq_length))}
        data['y'] = torch.tensor(y)
        return data

    def __len__(self):
        return len(self.dataset)

# %% [markdown]
# Ahora instanciaremos el dataset entero. Para este experimento, definiremos un tamaño máximo de secuencia de 2048 **tokens**. Que según nuestra intuición arriba, debería ser suficiente para la tarea.

# %%
max_len = 512
spanish_news_dataset = SpanishNewsDataset(tokenize_text, full_dataset, seq_length=max_len)
assert len(spanish_news_dataset) == len(full_dataset)

# %% [markdown]
# Y luego, procedemos a hacer el train-val-test split y crear los dataloaders.

# %%
# Extraer labels
labels = [int(spanish_news_dataset[i]["y"]) for i in range(len(spanish_news_dataset))]

# Indices de todo el dataset
indices = list(range(len(spanish_news_dataset)))

# Split estratificado: train (80%), temp (20%)
train_idx, temp_idx, _, temp_labels = train_test_split(
    indices, labels, test_size=0.2, stratify=labels, random_state=42
)

# Split estratificado: val (10%), test (10%) a partir del temp (20%)
val_idx, test_idx = train_test_split(
    temp_idx, test_size=0.5, stratify=temp_labels, random_state=42
)

# Construir Subsets
train_dataset = Subset(spanish_news_dataset, train_idx)
val_dataset   = Subset(spanish_news_dataset, val_idx)
test_dataset  = Subset(spanish_news_dataset, test_idx)

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

# %% [markdown]
# ### 5. Definición del modelo LSTM

# %% [markdown]
# Ahora vamos a configurar un módulo pytorch simple para este problema. Vamos ha utilizar los embeddings, que vendrían siendo los vectores de palabra. Pytorch nos ofrece una capa con la que directamente podemos entrenarlos a partir de los token ids obtenidos. El resto consistirá en invocar una capa LSTM seguida de una capa densa para la clasificación.
#
# Las redes recurrentes como las LSTM por diseño enlazan todas las dimensiones del vector de entrada, formando así la secuencia, la estructura natural que necesitamos representar.

# %%
class LSTMBlock(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, num_layers=2, dropout=0.2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
    
    def forward(self, x):
        embedded = self.embedding(x)
        output, (hidden, _) = self.lstm(embedded)
        return hidden[-1]

# %% [markdown]
# ### 6. Definición del clasificador

# %% [markdown]
# Finalmente, definimos el modelo en si. Este modelo constará de 3 capas:
#
# - La tokenización, tal como la definimos anteriormente.
# - El bloque LSTM, que acabamos de decinir.
# - Una capa densa adicional que servirá como clasificador de aquello que nos entregue la capa del transformer.
#
# Como este es un LightningModule, aquí definiremos el resto de funciones utilitarias para el entrenamiento de la tarea.

# %%
class SpanishNewsClassifierWithLSTM(LightningModule):

    def __init__(self, vocab_size: int, num_classes: int, emb_dim: int, hidden_dim: int = 128):
        super(SpanishNewsClassifierWithLSTM, self).__init__()
        self.num_classes = num_classes
        self.lstm = LSTMBlock(vocab_size, emb_dim, hidden_dim, num_classes)
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(hidden_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes),
            nn.LogSoftmax(dim=1)
        )

        self.train_acc = Accuracy(task='multiclass', num_classes=num_classes)
        self.val_acc = Accuracy(task='multiclass', num_classes=num_classes)
        self.test_acc = Accuracy(task='multiclass', num_classes=num_classes)

    def forward(self, x):
        embeddings = self.lstm(x)
        return self.classifier(embeddings)
    
    def training_step(self, batch, batch_idx):
        x, y = batch['input_ids'], batch['y']
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y)
        self.train_acc(y_hat, y)
        self.log('train-loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('train-acc', self.train_acc, prog_bar=True, on_step=False, on_epoch=True)
        return loss
    
    def validation_step(self, batch):
        x, y = batch['input_ids'], batch['y']
        y_hat = self(x)
        loss = F.cross_entropy(y_hat, y)
        self.val_acc(y_hat, y)
        self.log('val-loss', loss, prog_bar=True, on_step=False, on_epoch=True)
        self.log('val-acc', self.val_acc, prog_bar=True, on_step=False, on_epoch=True)
        return loss
    
    def test_step(self, batch):
        x, y = batch['input_ids'], batch['y']
        y_hat = self(x)
        self.test_acc(y_hat, y)
        self.log('test-acc', self.test_acc, prog_bar=True, on_step=False, on_epoch=True)

    def predict_step(self, batch):
        x = batch['input_ids']
        return self(x)

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=1e-3, weight_decay=1e-5)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", patience=2)
        return {"optimizer": optimizer, "lr_scheduler": scheduler, "monitor": "val-loss"}

    
model = SpanishNewsClassifierWithLSTM(vocab_size=len(vocab) + 1, num_classes=spanish_news_dataset.num_classes, emb_dim=256)

tb_logger = TensorBoardLogger('tb_logs', name='LSTMClassifier')
callbacks=[EarlyStopping(monitor='val-loss', patience=3, mode='min')]
trainer = Trainer(max_epochs=10, devices=1, logger=tb_logger, callbacks=callbacks, precision=32)

trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name       | Type               | Params | Mode
# ----------------------------------------------------------
# 0 | lstm       | LSTMBlock          | 2.9 M  | train
# 1 | classifier | Sequential         | 198 K  | train
# 2 | train_acc  | MulticlassAccuracy | 0      | train
# 3 | val_acc    | MulticlassAccuracy | 0      | train
# 4 | test_acc   | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 3.1 M     Trainable params
# 0         Non-trainable params
# 3.1 M     Total params
# 12.242    Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 452/452 [01:17<00:00,  5.83it/s, v_num=36]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 20.56it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 18.10it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 16.61it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 16.08it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 15.82it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 15.57it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 15.45it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 15.51it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 15.47it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 15.44it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 15.41it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 15.49it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 15.45it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 15.44it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 15.51it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 15.48it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 15.46it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 15.45it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 15.46it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 15.44it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 15.42it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 15.41it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 15.41it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 15.41it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 15.45it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 15.46it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 15.47it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 15.50it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 15.49it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 15.47it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 15.52it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 15.56it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 15.55it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 15.53it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 15.52it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 15.51it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 15.50it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 15.49it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 15.50it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 15.49it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 15.49it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:00, 15.48it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 15.48it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 15.50it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 15.50it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 15.49it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 15.51it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 15.52it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 15.53it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 15.53it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 15.56it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 15.56it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 15.55it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 15.55it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 15.55it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:03<00:00, 15.55it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 15.65it/s]
# Epoch 1: 100%|██████████| 452/452 [01:17<00:00,  5.81it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:07,  7.43it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:06,  8.88it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:05, 10.08it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:04, 11.22it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:04, 11.88it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:04, 12.26it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 12.51it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 12.75it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 12.98it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 13.19it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 13.28it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 13.41it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 13.51it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:01<00:03, 13.57it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:03, 13.66it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 13.73it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 13.84it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 13.98it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 14.02it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 14.07it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 14.11it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 14.15it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 14.24it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 14.29it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 14.34it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 14.36it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 14.40it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:02, 14.41it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:01, 14.46it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.48it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.50it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.53it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.57it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 14.59it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 14.62it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 14.67it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 14.73it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 14.78it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 14.79it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 14.80it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 14.81it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:01, 14.83it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 14.81it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 14.79it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 14.77it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 14.77it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 14.76it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 14.77it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 14.76it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 14.74it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 14.72it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 14.71it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 14.70it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 14.69it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 14.69it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:03<00:00, 14.68it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 14.79it/s]
# Epoch 2: 100%|██████████| 452/452 [01:17<00:00,  5.82it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.201]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 20.60it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 17.04it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 15.90it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 15.59it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 15.73it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 15.71it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 15.62it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 15.57it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 15.46it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 15.37it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 15.23it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 15.17it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 15.13it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 15.10it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 15.02it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 14.98it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 14.97it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 14.86it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 14.80it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 14.72it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 14.67it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 14.65it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 14.61it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 14.55it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 14.49it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 14.47it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 14.42it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:02, 14.37it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:01, 14.32it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.29it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.25it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.17it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 13.98it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 13.93it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 13.90it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 13.88it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 13.89it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 13.88it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 13.87it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 13.86it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:03<00:01, 13.86it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:01, 13.85it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 13.83it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 13.82it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 13.82it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 13.81it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 13.78it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 13.77it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 13.75it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 13.74it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 13.73it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 13.72it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 13.71it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:04<00:00, 13.70it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:04<00:00, 13.37it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:04<00:00, 13.44it/s]
# Epoch 3: 100%|██████████| 452/452 [01:17<00:00,  5.83it/s, v_num=36, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.194]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:03, 18.45it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 16.36it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 15.29it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 14.82it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 14.53it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 14.42it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 14.40it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 14.45it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 14.39it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 14.45it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 14.42it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 14.32it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 14.30it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:03, 14.28it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:02, 14.23it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 14.17it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 14.21it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 14.18it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 14.19it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 14.20it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 14.16it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 14.14it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 14.13it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 14.14it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 14.14it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 14.12it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 14.12it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:02, 14.13it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:01, 14.12it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.12it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.10it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.11it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.10it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 14.11it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 14.08it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 14.11it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 14.12it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:01, 14.14it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:00, 14.15it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 14.15it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 14.15it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 14.15it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 14.17it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 14.19it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 14.19it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 13.95it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 13.91it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 13.90it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 13.91it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 13.92it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 13.94it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:04<00:00, 13.97it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:04<00:00, 14.08it/s]
# Epoch 4: 100%|██████████| 452/452 [01:17<00:00,  5.81it/s, v_num=36, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 18.93it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 15.99it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 14.99it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 14.72it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 14.50it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 14.39it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 14.34it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 14.33it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 14.28it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 14.24it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 14.19it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 14.12it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 14.10it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:03, 14.07it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:02, 14.02it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 14.00it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 13.96it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 13.99it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 13.97it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 13.93it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 13.97it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 13.95it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 13.96it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 14.00it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 13.99it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 13.99it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 14.01it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:02, 14.00it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:01, 14.04it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.06it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.08it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.09it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.11it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 14.14it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 14.19it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 14.22it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 14.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 14.26it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 14.27it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 14.28it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 14.28it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:01, 14.29it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:00, 14.28it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 14.31it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 14.31it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 14.32it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 14.33it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 14.35it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 14.36it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 14.37it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 14.39it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 14.40it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 14.41it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 14.42it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 14.43it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:03<00:00, 14.43it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 14.53it/s]
# Epoch 5: 100%|██████████| 452/452 [01:17<00:00,  5.82it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.197]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 19.47it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 16.33it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 15.73it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 15.52it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 15.38it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 15.24it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 15.20it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 15.11it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 15.01it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 13.87it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 13.61it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 13.58it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 13.63it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:01<00:03, 13.76it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:03, 13.84it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 13.93it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 14.05it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 14.10it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 14.14it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 14.17it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 14.20it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 14.25it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 14.28it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 14.31it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 14.33it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 14.37it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 14.40it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:02, 14.41it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:01, 14.42it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.43it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.44it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.46it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.47it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 14.49it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 14.50it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 14.49it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 14.49it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 14.50it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 14.51it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 14.52it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 14.53it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:01, 14.52it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 14.54it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 14.58it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 14.58it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 14.59it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 14.62it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 14.62it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 14.62it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 14.62it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 14.62it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 14.66it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 14.66it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 14.65it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 14.66it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:03<00:00, 14.67it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 14.77it/s]
# Epoch 6: 100%|██████████| 452/452 [01:18<00:00,  5.77it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.194]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 19.93it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 17.56it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 16.47it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 15.81it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 15.43it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 15.28it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 15.15it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 15.28it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 15.29it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 15.31it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 15.23it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 15.18it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 15.24it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 15.18it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 15.18it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 15.13it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 15.11it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 15.08it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 15.11it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 15.11it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 15.05it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 15.04it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 14.99it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 15.04it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 15.02it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 15.02it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 15.02it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 14.99it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 14.98it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 14.96it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 14.95it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 14.99it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 14.97it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 14.94it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 14.93it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 14.93it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 14.95it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 14.96it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 14.94it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 14.94it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:01, 14.64it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:01, 14.56it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 14.53it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 14.53it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 14.53it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 14.52it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 14.53it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:03<00:00, 14.54it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:03<00:00, 14.55it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:03<00:00, 14.55it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 14.67it/s]
# Epoch 7: 100%|██████████| 452/452 [01:18<00:00,  5.76it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.202]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 20.21it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 16.73it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 15.88it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 15.54it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 15.50it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 15.30it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 15.12it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 15.04it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 14.94it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 14.87it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 14.76it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 14.66it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 14.61it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 14.52it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:02, 14.53it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:02, 14.52it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 14.51it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 14.03it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 13.84it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 13.75it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 13.69it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 13.65it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 13.62it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 13.57it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 13.52it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 13.50it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:02<00:02, 13.46it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:02<00:02, 13.44it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:02, 13.44it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:02, 13.44it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 13.42it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 13.41it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 13.40it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 13.40it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 13.39it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 13.39it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 13.38it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 13.37it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 13.37it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 13.36it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:03<00:01, 13.35it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:03<00:01, 13.33it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:01, 13.34it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 13.34it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 13.30it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 13.30it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 13.31it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 13.30it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 13.31it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 13.32it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 13.33it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 13.36it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:03<00:00, 13.40it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:04<00:00, 13.42it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:04<00:00, 13.44it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:04<00:00, 13.44it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:04<00:00, 13.56it/s]
# Epoch 8: 100%|██████████| 452/452 [01:20<00:00,  5.62it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.198]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:02, 20.53it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 16.19it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 15.42it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:03, 15.07it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:03, 14.84it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:03, 14.73it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:03, 14.68it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:03, 14.13it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:03, 13.32it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:03, 13.19it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 13.30it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:03, 13.36it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:03, 13.48it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:01<00:03, 13.53it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:03, 13.55it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:03, 13.60it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:02, 13.66it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:02, 13.72it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:02, 13.67it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 13.67it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 13.69it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 13.70it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 13.71it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 13.67it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 13.65it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:02, 13.62it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:02, 13.60it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:02<00:02, 13.61it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:02, 13.62it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:01, 13.64it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:01, 13.63it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 13.62it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 13.61it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 13.61it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 13.62it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 13.62it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 13.62it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 13.62it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 13.61it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:01, 13.60it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:03<00:01, 13.59it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:03<00:01, 13.58it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:01, 13.58it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 13.57it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 13.52it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 13.47it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 13.46it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 13.46it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 13.46it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 13.44it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 13.23it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:03<00:00, 13.11it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:04<00:00, 13.08it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:04<00:00, 13.06it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:04<00:00, 13.05it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:04<00:00, 13.06it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:04<00:00, 13.15it/s]
# Epoch 9: 100%|██████████| 452/452 [01:20<00:00,  5.59it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.201]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:03, 18.65it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:03, 15.38it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:03, 14.60it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:05, 10.30it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:04, 10.46it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:04, 10.76it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:04, 11.01it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:04, 11.25it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:04, 11.45it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:04, 11.62it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:03, 11.73it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:01<00:03, 11.84it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:01<00:03, 11.96it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:01<00:03, 12.05it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:03, 12.16it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:03, 12.25it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:01<00:03, 12.36it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:01<00:03, 12.42it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:01<00:03, 12.47it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:02, 12.54it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:02, 12.60it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:02, 12.65it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:02, 12.70it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:02, 12.71it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:02, 12.73it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:02<00:02, 12.78it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:02<00:02, 12.81it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:02<00:02, 12.84it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:02<00:02, 12.89it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:02<00:02, 12.91it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:02<00:02, 12.94it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:02<00:01, 12.96it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:02<00:01, 12.99it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:02<00:01, 13.03it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:02<00:01, 13.06it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:02<00:01, 13.09it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:02<00:01, 13.10it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:02<00:01, 13.14it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:02<00:01, 13.19it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:03<00:01, 13.22it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:03<00:01, 13.23it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:03<00:01, 13.25it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:03<00:01, 13.27it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:03<00:00, 13.01it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:03<00:00, 12.95it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:03<00:00, 12.92it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:03<00:00, 12.92it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:03<00:00, 12.91it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:03<00:00, 12.93it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:03<00:00, 12.93it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:03<00:00, 12.93it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:04<00:00, 12.94it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:04<00:00, 12.93it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:04<00:00, 12.93it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:04<00:00, 12.93it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:04<00:00, 12.93it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:04<00:00, 13.03it/s]
# Epoch 9: 100%|██████████| 452/452 [01:25<00:00,  5.30it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.203]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 452/452 [01:25<00:00,  5.29it/s, v_num=36, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.203]

# %%
def objective(trial):
    # Definir espacio de búsqueda
    hidden_dim = trial.suggest_categorical("hidden_dim", [64, 128, 256])
    dropout = trial.suggest_float("dropout", 0.1, 0.5)
    lr = trial.suggest_loguniform("lr", 1e-4, 1e-2)

    # Modelo con params del trial
    model = SpanishNewsClassifierWithLSTM(
        vocab_size=len(vocab)+1,
        num_classes=spanish_news_dataset.num_classes,
        emb_dim=128,
        hidden_dim=hidden_dim
    )
    model.classifier[3].p = dropout  # ajustar dropout dinámicamente

    trainer = Trainer(
        max_epochs=10,
        logger=TensorBoardLogger("optuna_logs", name=f"trial_{trial.number}"),
        enable_checkpointing=False
    )

    trainer.fit(model, train_loader, val_loader)
    # Retornar la métrica que quieres optimizar
    return trainer.callback_metrics["val-acc"].item()

# Ejecutar búsqueda
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)

print("Best params:", study.best_params)
# Out:
# [I 2025-08-23 10:25:48,117] A new study created in memory with name: no-name-288af785-377f-49b0-888b-c28c5dfa6711
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name       | Type               | Params | Mode
# ----------------------------------------------------------
# 0 | lstm       | LSTMBlock          | 1.3 M  | train
# 1 | classifier | Sequential         | 165 K  | train
# 2 | train_acc  | MulticlassAccuracy | 0      | train
# 3 | val_acc    | MulticlassAccuracy | 0      | train
# 4 | test_acc   | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 1.5 M     Trainable params
# 0         Non-trainable params
# 1.5 M     Total params
# 6.060     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 452/452 [00:48<00:00,  9.39it/s, v_num=3]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 41.40it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:01, 29.61it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:01, 28.00it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 26.45it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 25.56it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 25.19it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:01, 25.10it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:01, 25.03it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:01, 24.81it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:01, 24.62it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:01, 24.61it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:01, 24.54it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:01, 24.56it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 24.44it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 24.32it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 24.20it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 24.14it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 24.07it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 24.05it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 24.00it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 23.99it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:00<00:01, 23.99it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:00<00:01, 23.95it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 23.95it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 23.87it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 23.86it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 23.89it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 23.90it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 23.92it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 23.91it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 23.97it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 23.94it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 23.80it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:00, 23.77it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:00, 23.68it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 23.60it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 23.54it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 23.50it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 23.48it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 23.44it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 23.36it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 23.31it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 23.27it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:01<00:00, 23.25it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:01<00:00, 23.19it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:01<00:00, 23.14it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 23.10it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 23.08it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 23.02it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 22.91it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 22.81it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 22.70it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 22.61it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 22.42it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 22.35it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 22.26it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 22.29it/s]
# Epoch 1: 100%|██████████| 452/452 [00:47<00:00,  9.50it/s, v_num=3, val-loss=1.610, val-acc=0.199, train-loss=1.610, train-acc=0.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 38.21it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 27.31it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 24.97it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 23.64it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 22.98it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 22.97it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 22.89it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 22.82it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 22.75it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 22.73it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 22.63it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:01, 22.57it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:01, 22.61it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 22.54it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 22.54it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 22.50it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 22.49it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 22.41it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 22.36it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 22.32it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 22.31it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:00<00:01, 22.33it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 22.36it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 22.30it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 22.27it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 22.28it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 22.27it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 22.29it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 22.28it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 22.25it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 22.28it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 22.25it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 22.30it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 22.31it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 22.29it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 22.25it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 22.29it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:01<00:00, 22.30it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 22.29it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 22.29it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 22.30it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 22.29it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 22.29it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 22.28it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 22.26it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 22.27it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 22.42it/s]
# Epoch 2: 100%|██████████| 452/452 [00:46<00:00,  9.83it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.199]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 32.14it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 24.26it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 22.03it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 21.56it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 20.97it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 20.81it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 20.62it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 20.44it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 20.37it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 20.37it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 20.34it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 20.35it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 20.28it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 20.33it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 20.26it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:02, 20.22it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 20.28it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 20.28it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 20.26it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 20.24it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:01, 20.21it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:01, 20.16it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 20.20it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 18.92it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 18.72it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 18.68it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 18.76it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 18.85it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 18.96it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 19.03it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 19.12it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 19.16it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 19.23it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 19.29it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:01, 19.34it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:01, 19.40it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:01, 19.48it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 19.57it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 19.62it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:00, 19.70it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:00, 19.74it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:00, 19.79it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 19.84it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 19.92it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 19.94it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 20.00it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 20.00it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 19.98it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 19.96it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 19.99it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 20.02it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 20.05it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 20.08it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 20.12it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 20.16it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 20.18it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 20.34it/s]
# Epoch 3: 100%|██████████| 452/452 [00:46<00:00,  9.64it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.191]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 31.15it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 23.54it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 21.52it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 21.05it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 20.50it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 19.86it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 19.77it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 19.44it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 19.34it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 19.28it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 19.14it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 19.09it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 19.10it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 19.20it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 19.21it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:02, 19.20it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:02, 19.28it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:02, 19.33it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 19.27it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:01<00:01, 19.22it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:01, 19.16it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:01, 19.18it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 19.23it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 19.29it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 19.30it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 19.32it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 19.36it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 19.42it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 19.46it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 19.49it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 19.45it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 19.45it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 19.49it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 19.54it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:01, 19.57it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:01, 19.60it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:01, 19.61it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 19.64it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 19.69it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:02<00:00, 19.80it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:02<00:00, 19.86it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:00, 19.90it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 19.99it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 20.05it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 20.12it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 20.17it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 20.22it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 20.29it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 20.34it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 20.37it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 20.40it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 20.42it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 20.46it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 20.47it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 20.51it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 20.55it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 20.70it/s]
# Epoch 4: 100%|██████████| 452/452 [00:47<00:00,  9.50it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.192]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 39.43it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:01, 28.89it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 26.34it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 24.89it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 24.32it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 24.14it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 23.91it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 23.50it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 23.31it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 23.23it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 22.77it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:01, 22.56it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:01, 22.31it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 22.15it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 21.98it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 21.87it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 21.82it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 21.76it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 21.68it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 21.45it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 21.34it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:01, 21.27it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 21.20it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 21.15it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 21.10it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 21.09it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 21.08it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 21.07it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 20.98it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 20.93it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 20.83it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 20.78it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 20.73it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 20.65it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:01, 20.59it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:01, 20.53it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 20.49it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 20.52it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 20.53it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 20.54it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 20.53it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:02<00:00, 20.53it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 20.52it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 20.51it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 20.50it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 20.51it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 20.51it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 20.52it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 20.51it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 20.48it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 20.49it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 20.47it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 20.48it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 20.47it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 20.48it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 20.48it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 20.62it/s]
# Epoch 5: 100%|██████████| 452/452 [00:48<00:00,  9.39it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.196]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 36.09it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 26.11it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 24.38it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 23.43it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 23.07it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 22.81it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 22.51it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 22.36it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 22.17it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 21.99it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 21.85it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 21.86it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 21.79it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 21.64it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 21.57it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 21.56it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 21.53it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 21.47it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 21.52it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 21.50it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 21.46it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:01, 21.45it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 21.45it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 21.47it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 21.46it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 21.48it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 21.50it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 21.59it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 21.64it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 21.73it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 21.75it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 21.74it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 21.72it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 21.72it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:01, 21.77it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 21.76it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 21.73it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 21.72it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 21.72it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 21.74it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 21.75it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 21.72it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 21.69it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 21.69it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 21.67it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 21.65it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 21.66it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 21.65it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 21.66it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 21.64it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 21.65it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 21.62it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 21.47it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 21.46it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 21.49it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 21.51it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 21.65it/s]
# Epoch 6: 100%|██████████| 452/452 [00:47<00:00,  9.57it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.200]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 34.69it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 25.70it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 23.91it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 22.87it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 22.37it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 22.19it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 21.84it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 21.37it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 21.00it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 21.03it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 20.95it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 20.86it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 20.78it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 20.76it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:02, 20.70it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 20.70it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 20.69it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 20.61it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 20.63it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 20.53it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:01<00:01, 20.54it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:01<00:01, 20.50it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 20.52it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 20.53it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 20.52it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 20.51it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 20.62it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 20.70it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 20.81it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 20.88it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 20.94it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 20.97it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 21.01it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 21.06it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:01, 21.08it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 21.15it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 21.20it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 21.22it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 21.26it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 21.29it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 21.30it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 21.37it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:02<00:00, 21.39it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 21.45it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 21.47it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 21.49it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 21.53it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 21.55it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 21.57it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 21.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 21.59it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 21.60it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 21.61it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 21.61it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 21.58it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 21.59it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 21.73it/s]
# Epoch 7: 100%|██████████| 452/452 [00:48<00:00,  9.40it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.195]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 37.20it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:01, 28.43it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 25.98it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 24.97it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 24.51it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 24.17it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 23.77it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 23.55it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 23.42it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 23.33it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:01, 23.21it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:01, 23.20it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:01, 23.07it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 22.94it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 22.87it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 22.84it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 22.82it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 22.85it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 22.71it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 22.71it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 22.68it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:00<00:01, 22.66it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 22.67it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 22.66it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 22.65it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 22.55it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 22.51it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 22.47it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 22.41it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 22.36it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 22.35it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 22.30it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 22.30it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 22.28it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:00, 22.21it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 22.18it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 22.15it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 22.14it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 22.06it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 22.06it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 22.00it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 22.01it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 22.00it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:02<00:00, 21.99it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 21.98it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 21.97it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 21.98it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 22.00it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 21.99it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 21.97it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 21.97it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 21.98it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 21.96it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 21.79it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 21.77it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 21.81it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 21.95it/s]
# Epoch 8: 100%|██████████| 452/452 [00:47<00:00,  9.42it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.198]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 33.66it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 26.03it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 23.39it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 21.97it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 21.41it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 21.22it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 21.18it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 21.49it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 21.52it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 21.07it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 21.04it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:02, 21.20it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:02, 21.23it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:02, 21.34it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 21.43it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 21.42it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 21.57it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 21.67it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 21.75it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 21.83it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 21.92it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:00<00:01, 22.01it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 22.04it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 22.07it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 22.08it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 22.12it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 22.17it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 22.16it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 22.20it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 22.25it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 22.31it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 22.30it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 22.33it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 22.34it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:00, 22.40it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 22.45it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 22.44it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 22.46it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 22.46it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 22.48it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 22.49it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 22.54it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 22.56it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:01<00:00, 22.55it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:01<00:00, 22.54it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 22.55it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 22.58it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 22.57it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 22.58it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 22.59it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 22.58it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 22.59it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 22.59it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 22.62it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 22.60it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 22.61it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 22.77it/s]
# Epoch 9: 100%|██████████| 452/452 [00:48<00:00,  9.38it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.203]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:01, 31.33it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:02, 25.51it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:02, 24.39it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:02, 23.99it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:02, 23.47it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:02, 23.16it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:02, 22.99it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:02, 22.84it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:00<00:02, 22.64it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:00<00:02, 22.67it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:00<00:02, 22.68it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:00<00:01, 22.65it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:00<00:01, 22.67it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:00<00:01, 22.69it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:00<00:01, 22.62it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:00<00:01, 22.57it/s]
# Validation DataLoader 0:  30%|██▉       | 17/57 [00:00<00:01, 22.67it/s]
# Validation DataLoader 0:  32%|███▏      | 18/57 [00:00<00:01, 22.61it/s]
# Validation DataLoader 0:  33%|███▎      | 19/57 [00:00<00:01, 22.59it/s]
# Validation DataLoader 0:  35%|███▌      | 20/57 [00:00<00:01, 22.54it/s]
# Validation DataLoader 0:  37%|███▋      | 21/57 [00:00<00:01, 22.56it/s]
# Validation DataLoader 0:  39%|███▊      | 22/57 [00:00<00:01, 22.51it/s]
# Validation DataLoader 0:  40%|████      | 23/57 [00:01<00:01, 22.50it/s]
# Validation DataLoader 0:  42%|████▏     | 24/57 [00:01<00:01, 22.48it/s]
# Validation DataLoader 0:  44%|████▍     | 25/57 [00:01<00:01, 22.51it/s]
# Validation DataLoader 0:  46%|████▌     | 26/57 [00:01<00:01, 22.54it/s]
# Validation DataLoader 0:  47%|████▋     | 27/57 [00:01<00:01, 22.52it/s]
# Validation DataLoader 0:  49%|████▉     | 28/57 [00:01<00:01, 22.49it/s]
# Validation DataLoader 0:  51%|█████     | 29/57 [00:01<00:01, 22.51it/s]
# Validation DataLoader 0:  53%|█████▎    | 30/57 [00:01<00:01, 22.50it/s]
# Validation DataLoader 0:  54%|█████▍    | 31/57 [00:01<00:01, 22.45it/s]
# Validation DataLoader 0:  56%|█████▌    | 32/57 [00:01<00:01, 22.42it/s]
# Validation DataLoader 0:  58%|█████▊    | 33/57 [00:01<00:01, 22.45it/s]
# Validation DataLoader 0:  60%|█████▉    | 34/57 [00:01<00:01, 22.45it/s]
# Validation DataLoader 0:  61%|██████▏   | 35/57 [00:01<00:00, 22.45it/s]
# Validation DataLoader 0:  63%|██████▎   | 36/57 [00:01<00:00, 22.43it/s]
# Validation DataLoader 0:  65%|██████▍   | 37/57 [00:01<00:00, 22.45it/s]
# Validation DataLoader 0:  67%|██████▋   | 38/57 [00:01<00:00, 22.45it/s]
# Validation DataLoader 0:  68%|██████▊   | 39/57 [00:01<00:00, 22.48it/s]
# Validation DataLoader 0:  70%|███████   | 40/57 [00:01<00:00, 22.47it/s]
# Validation DataLoader 0:  72%|███████▏  | 41/57 [00:01<00:00, 22.47it/s]
# Validation DataLoader 0:  74%|███████▎  | 42/57 [00:01<00:00, 22.50it/s]
# Validation DataLoader 0:  75%|███████▌  | 43/57 [00:01<00:00, 22.51it/s]
# Validation DataLoader 0:  77%|███████▋  | 44/57 [00:01<00:00, 22.48it/s]
# Validation DataLoader 0:  79%|███████▉  | 45/57 [00:02<00:00, 22.47it/s]
# Validation DataLoader 0:  81%|████████  | 46/57 [00:02<00:00, 22.45it/s]
# Validation DataLoader 0:  82%|████████▏ | 47/57 [00:02<00:00, 22.42it/s]
# Validation DataLoader 0:  84%|████████▍ | 48/57 [00:02<00:00, 22.39it/s]
# Validation DataLoader 0:  86%|████████▌ | 49/57 [00:02<00:00, 22.39it/s]
# Validation DataLoader 0:  88%|████████▊ | 50/57 [00:02<00:00, 22.34it/s]
# Validation DataLoader 0:  89%|████████▉ | 51/57 [00:02<00:00, 22.35it/s]
# Validation DataLoader 0:  91%|█████████ | 52/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  93%|█████████▎| 53/57 [00:02<00:00, 22.30it/s]
# Validation DataLoader 0:  95%|█████████▍| 54/57 [00:02<00:00, 22.31it/s]
# Validation DataLoader 0:  96%|█████████▋| 55/57 [00:02<00:00, 22.32it/s]
# Validation DataLoader 0:  98%|█████████▊| 56/57 [00:02<00:00, 22.32it/s]
# Validation DataLoader 0: 100%|██████████| 57/57 [00:02<00:00, 22.46it/s]
# Epoch 9: 100%|██████████| 452/452 [00:50<00:00,  8.91it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.190]
# `Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|██████████| 452/452 [00:50<00:00,  8.91it/s, v_num=3, val-loss=1.610, val-acc=0.200, train-loss=1.610, train-acc=0.190]
# [I 2025-08-23 10:34:10,869] Trial 0 finished with value: 0.20044296979904175 and parameters: {'hidden_dim': 64, 'dropout': 0.17765143036521747, 'lr': 0.0001462935125020138}. Best is trial 0 with value: 0.20044296979904175.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name       | Type               | Params | Mode
# ----------------------------------------------------------
# 0 | lstm       | LSTMBlock          | 2.2 M  | train
# 1 | classifier | Sequential         | 264 K  | train
# 2 | train_acc  | MulticlassAccuracy | 0      | train
# 3 | val_acc    | MulticlassAccuracy | 0      | train
# 4 | test_acc   | MulticlassAccuracy | 0      | train
# ----------------------------------------------------------
# 2.5 M     Trainable params
# 0         Non-trainable params
# 2.5 M     Total params
# 9.807     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 452/452 [02:31<00:00,  2.98it/s, v_num=1]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/57 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/57 [00:00<00:05, 10.65it/s]
# Validation DataLoader 0:   4%|▎         | 2/57 [00:00<00:05,  9.56it/s]
# Validation DataLoader 0:   5%|▌         | 3/57 [00:00<00:05,  9.22it/s]
# Validation DataLoader 0:   7%|▋         | 4/57 [00:00<00:05,  9.12it/s]
# Validation DataLoader 0:   9%|▉         | 5/57 [00:00<00:05,  9.06it/s]
# Validation DataLoader 0:  11%|█         | 6/57 [00:00<00:05,  8.97it/s]
# Validation DataLoader 0:  12%|█▏        | 7/57 [00:00<00:05,  8.85it/s]
# Validation DataLoader 0:  14%|█▍        | 8/57 [00:00<00:05,  8.80it/s]
# Validation DataLoader 0:  16%|█▌        | 9/57 [00:01<00:05,  8.72it/s]
# Validation DataLoader 0:  18%|█▊        | 10/57 [00:01<00:05,  8.71it/s]
# Validation DataLoader 0:  19%|█▉        | 11/57 [00:01<00:05,  8.71it/s]
# Validation DataLoader 0:  21%|██        | 12/57 [00:01<00:05,  8.73it/s]
# Validation DataLoader 0:  23%|██▎       | 13/57 [00:01<00:05,  8.72it/s]
# Validation DataLoader 0:  25%|██▍       | 14/57 [00:01<00:04,  8.73it/s]
# Validation DataLoader 0:  26%|██▋       | 15/57 [00:01<00:04,  8.73it/s]
# Validation DataLoader 0:  28%|██▊       | 16/57 [00:01<00:04,  8.74it/s]
# ...
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\jepil\anaconda3\envs\nlp\lib\site-packages\optuna\study\_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\jepil\AppData\Local\Temp\ipykernel_19056\915440125.py", line 25, in objective
#     trainer.fit(model, train_loader, val_loader)
#   File "C:\Users\jepil\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py", line 539, in fit
#     call._call_and_handle_interrupt(
#   File "C:\Users\jepil\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\call.py", line 64, in _call_and_handle_interrupt
#     exit(1)
# NameError: name 'exit' is not defined
# [W 2025-08-23 10:58:56,106] Trial 1 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:575, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     569 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     570     self.state.fn,
#     571     ckpt_path,
#     572     model_provided=True,
#     573     model_connected=self.lightning_module is not None,
#     574 )
# --> 575 self._run(model, ckpt_path=ckpt_path)
#     577 assert self.state.stopped
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:982, in Trainer._run(self, model, ckpt_path)
#     979 # ----------------------------
#     980 # RUN THE TRAINER
#     981 # ----------------------------
# --> 982 results = self._run_stage()
#     984 # ----------------------------
#     985 # POST-Training CLEAN UP
#     986 # ----------------------------
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:1026, in Trainer._run_stage(self)
#    1025 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1026     self.fit_loop.run()
#    1027 return None
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\fit_loop.py:216, in _FitLoop.run(self)
#     215 self.on_advance_start()
# --> 216 self.advance()
#     217 self.on_advance_end()
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\fit_loop.py:455, in _FitLoop.advance(self)
#     454 assert self._data_fetcher is not None
# --> 455 self.epoch_loop.run(self._data_fetcher)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:150, in _TrainingEpochLoop.run(self, data_fetcher)
#     149 try:
# --> 150     self.advance(data_fetcher)
#     151     self.on_advance_end(data_fetcher)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\training_epoch_loop.py:320, in _TrainingEpochLoop.advance(self, data_fetcher)
#     318 if trainer.lightning_module.automatic_optimization:
#     319     # in automatic optimization, there can only be one optimizer
# --> 320     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     321 else:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:192, in _AutomaticOptimization.run(self, optimizer, batch_idx, kwargs)
#     187 # ------------------------------
#     188 # BACKWARD PASS
#     189 # ------------------------------
#     190 # gradient update with accumulated gradients
#     191 else:
# --> 192     self._optimizer_step(batch_idx, closure)
#     194 result = closure.consume_result()
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:270, in _AutomaticOptimization._optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     269 # model hook
# --> 270 call._call_lightning_module_hook(
#     271     trainer,
#     272     "optimizer_step",
#     273     trainer.current_epoch,
#     274     batch_idx,
#     275     optimizer,
#     276     train_step_and_backward_closure,
#     277 )
#     279 if not should_accumulate:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\call.py:171, in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     170 with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 171     output = fn(*args, **kwargs)
#     173 # restore current_fx when nested context
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\core\module.py:1302, in LightningModule.optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1278 r"""Override this method to adjust the default way the :class:`~pytorch_lightning.trainer.trainer.Trainer` calls
#    1279 the optimizer.
#    1280
#    (...)
#    1300
#    1301 """
# -> 1302 optimizer.step(closure=optimizer_closure)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\core\optimizer.py:154, in LightningOptimizer.step(self, closure, **kwargs)
#     153 assert self._strategy is not None
# --> 154 step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     156 self._on_after_step()
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\strategies\strategy.py:239, in Strategy.optimizer_step(self, optimizer, closure, model, **kwargs)
#     238 assert isinstance(model, pl.LightningModule)
# --> 239 return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\plugins\precision\precision.py:123, in Precision.optimizer_step(self, optimizer, model, closure, **kwargs)
#     122 closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 123 return optimizer.step(closure=closure, **kwargs)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\optim\optimizer.py:493, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     489             raise RuntimeError(
#     490                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     491             )
# --> 493 out = func(*args, **kwargs)
#     494 self._optimizer_step_code()
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\optim\adamw.py:220, in AdamW.step(self, closure)
#     219     with torch.enable_grad():
# --> 220         loss = closure()
#     222 for group in self.param_groups:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\plugins\precision\precision.py:109, in Precision._wrap_closure(self, model, optimizer, closure)
#     102 """This double-closure allows makes sure the ``closure`` is executed before the ``on_before_optimizer_step``
#     103 hook is called.
#     104
#    (...)
#     107
#     108 """
# --> 109 closure_result = closure()
#     110 self._after_closure(model, optimizer)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:146, in Closure.__call__(self, *args, **kwargs)
#     144 @override
#     145 def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 146     self._result = self.closure(*args, **kwargs)
#     147     return self._result.loss
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     115 with ctx_factory():
# --> 116     return func(*args, **kwargs)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:140, in Closure.closure(self, *args, **kwargs)
#     139 if self._backward_fn is not None and step_output.closure_loss is not None:
# --> 140     self._backward_fn(step_output.closure_loss)
#     142 return step_output
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\loops\optimization\automatic.py:241, in _AutomaticOptimization._make_backward_fn.<locals>.backward_fn(loss)
#     240 def backward_fn(loss: Tensor) -> None:
# --> 241     call._call_strategy_hook(self.trainer, "backward", loss, optimizer)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\call.py:323, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     322 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 323     output = fn(*args, **kwargs)
#     325 # restore current_fx when nested context
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\strategies\strategy.py:213, in Strategy.backward(self, closure_loss, optimizer, *args, **kwargs)
#     211 closure_loss = self.precision_plugin.pre_backward(closure_loss, self.lightning_module)
# --> 213 self.precision_plugin.backward(closure_loss, self.lightning_module, optimizer, *args, **kwargs)
#     215 closure_loss = self.precision_plugin.post_backward(closure_loss, self.lightning_module)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\plugins\precision\precision.py:73, in Precision.backward(self, tensor, model, optimizer, *args, **kwargs)
#      62 r"""Performs the actual backpropagation.
#      63
#      64 Args:
#    (...)
#      71
#      72 """
# ---> 73 model.backward(tensor, *args, **kwargs)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\core\module.py:1097, in LightningModule.backward(self, loss, *args, **kwargs)
#    1096 else:
# -> 1097     loss.backward(*args, **kwargs)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\anaconda3\envs\nlp\lib\site-packages\torch\autograd\graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 31
#      29 # Ejecutar búsqueda
#      30 study = optuna.create_study(direction="maximize")
# ---> 31 study.optimize(objective, n_trials=20)
#      33 print("Best params:", study.best_params)
#
# File ~\anaconda3\envs\nlp\lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~\anaconda3\envs\nlp\lib\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~\anaconda3\envs\nlp\lib\site-packages\optuna\study\_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File ~\anaconda3\envs\nlp\lib\site-packages\optuna\study\_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[96], line 25, in objective(trial)
#      17 model.classifier[3].p = dropout  # ajustar dropout dinámicamente
#      19 trainer = Trainer(
#      20     max_epochs=10,
#      21     logger=TensorBoardLogger("optuna_logs", name=f"trial_{trial.number}"),
#      22     enable_checkpointing=False
#      23 )
# ---> 25 trainer.fit(model, train_loader, val_loader)
#      26 # Retornar la métrica que quieres optimizar
#      27 return trainer.callback_metrics["val-acc"].item()
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\trainer.py:539, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     537 self.state.status = TrainerStatus.RUNNING
#     538 self.training = True
# --> 539 call._call_and_handle_interrupt(
#     540     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     541 )
#
# File ~\anaconda3\envs\nlp\lib\site-packages\pytorch_lightning\trainer\call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Observemos el proceso de entrenamiento

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir tb_logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 20796), started 1 day, 12:15:40 ago. (Use '!kill 20796' to kill it.)
#       <iframe id="tensorboard-frame-76988063a4913ea4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-76988063a4913ea4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ### 7. Evaluación de desempeño del modelo

# %% [markdown]
# Realizamos la validación contra el conjunto de prueba.

# %%
model.eval()
trainer.test(model, test_loader)
# Out:
# Testing DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 15.30it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test-acc          │    0.20044296979904175    │
# └───────────────────────────┴───────────────────────────┘
# [{'test-acc': 0.20044296979904175}]

# %% [markdown]
# ### 8. Resultados

# %% [markdown]
# Finalmente, vamos a hacer uso del modelo y ver que tan bueno es para la clasificación de titulares de noticias.

# %%
predictions = trainer.predict(model, test_loader)
predictions = torch.cat(predictions, dim=0)
predictions = torch.argmax(predictions, dim=-1)
predictions = [spanish_news_dataset.id_2_class_map[pred] for pred in predictions.numpy()]
# Out:
# Predicting DataLoader 0: 100%|██████████| 57/57 [00:03<00:00, 15.66it/s]

# %%
test_indices = test_dataset.indices
df = pd.DataFrame(data={
    "texto": full_dataset[test_indices]['text'],
    "tokens": [tokenize_text(v) for v in full_dataset[test_indices]['text']],
    "categoría": full_dataset[test_indices]['label'],
    'predicción': predictions
}, index=test_indices)

id_2_token = {v: k for k, v in vocab.items()}

df['tokens_string'] = df.tokens.apply(lambda t: ' '.join([id_2_token[i] for i in t]))
df = df[["texto", "tokens", "tokens_string", "categoría", "predicción"]]
df.style.set_table_styles(
    [
        {'selector': 'td', 'props': [('word-wrap', 'break-word')]}
    ]
)
df.head(15)
# Out:
#                                                   texto  \
# 6281  Declaración de renta Se viene la declaración d...
# 8629  Vacunas covid Vacunas anticovid: lo que debe s...
# 5696  Gasolina ¿Más inflación? ABC de la relación en...
# 1161  Vehículos Siguen en aumento: matrículas nuevas...
# 3112  Catar 2022 Marruecos vs. Croacia: reviva los m...
# 5158  Congreso de la República ¿No se han graduado? ...
# 175   Empleo La petición de Mintrabajo para generar ...
# 1353  Salud mental Así ayuda la música a mejorar la ...
# 1130  Crisis en Ucrania Exportación de granos se vol...
# 3465  Ministerio de Salud Colombia firmó acuerdo par...
# 2929  Niños ¿Gripes mal cuidadas pueden ser fatales?...
# 7451  Trabajo ¡Pilas! Los riesgos laborales que más ...
# 1224  Catar 2022 ¿Tranquilidad? Di María y De Paul p...
# 4585  Metaverso Meta muestra las ideas en las que es...
# 4578  Colombianos en el exterior El top 10 de las ci...
#
#                                                  tokens  \
# 6281  [686, 1559, 3275, 686, 1559, 570, 7270, 92, 27...
# 8629  [270, 428, 270, 274, 93, 492, 412, 408, 172, 6...
# 5696  [1554, 69, 990, 6146, 263, 467, 1554, 989, 496...
# 1161  [60, 275, 467, 456, 26, 1919, 1782, 1759, 409,...
# 3112  [386, 893, 33, 2077, 1608, 8, 215, 451, 275, 4...
# 5158  [763, 764, 3362, 66, 5498, 763, 162, 104, 469,...
# 175   [784, 1517, 1518, 720, 812, 775, 383, 288, 123...
# 1353  [6, 2060, 284, 512, 3353, 8, 6, 2060, 4242, 23...
# 1130  [2181, 131, 3119, 511, 1596, 3208, 3363, 136, ...
# 3465  [172, 6, 18, 569, 373, 1263, 270, 2040, 2214, ...
# 2929  [194, 170, 1534, 2179, 109, 156, 1736, 194, 23...
# 7451  [399, 4093, 1621, 1238, 69, 648, 3222, 493, 23...
# 1224  [386, 1100, 1895, 1401, 13, 384, 914, 795, 575...
# 4585  [293, 859, 100, 301, 399, 293, 123, 1015, 788,...
# 4578  [379, 1853, 497, 1759, 409, 4242, 235, 68, 327...
#
#                                           tokens_string   categoría predicción
# 6281  declar rent vien declar rent sancion expon si ...    economia   colombia
# 8629  vacun cov vacun anticov deb sab dosis refuerz ...       salud   colombia
# 5696  gasolin mas inflacion abc relacion aument gaso...    economia   colombia
# 1161  vehicul sig aument matricul nuev automovil cre...    economia   colombia
# 3112  cat marruec vs croaci reviv mejor moment part ...    deportes   colombia
# 5158  congres republ gradu nivel academ congres estu...    colombia   colombia
# 175   emple peticion mintrabaj gener cambi economi p...    economia   colombia
# 1353  salud mental asi ayud music mejor salud mental...       salud   colombia
# 1130  crisis ucrani export gran volvi impos bloque r...    economia   colombia
# 3465  ministeri salud colombi firm acuerd fabric vac...       salud   colombia
# 2929  nin grip mal cuid pued ser fatal nin fallec ca...       salud   colombia
# 7451  trabaj pil riesg laboral mas muert provoc tota...    economia   colombia
# 1224  cat tranquil di mari paul particip ultim entre...    deportes   colombia
# 4585  metavers met muestr ide trabaj metavers empres...  tecnologia   colombia
# 4578  colombian exterior top ciudad mayor calid vid ...    economia   colombia

# %%
errors = df[df['categoría'] != df['predicción']]
errors.head(15)

# %%
df['predicción'].unique()

# %% [markdown]
# ### 9. Conclusiones

# %% [markdown]
# #### Eficacia del flujo de análisis
#
# - Se implementó un pipeline de clasificación multiclase sobre títulos de noticias en español utilizando un modelo basado en LSTM.
# - El bloque LSTM actuó como featurizer, extrayendo representaciones de las secuencias de entrada a partir de las cuales se realizaron las predicciones.
#
# #### Rendimiento del modelo
#
# - El modelo alcanzó un accuracy de 0.2, lo que indica un desempeño bajo para la tarea de clasificación.
# - Este resultado refleja que, en su configuración actual y sin optimización de hiperparámetros, el modelo no logra capturar de manera suficiente las características del texto para diferenciar entre las clases.
#
# #### Limitaciones observadas
#
# - El tiempo de entrenamiento fue elevado, lo cual es consistente con la naturaleza secuencial de las LSTM, donde en cada paso temporal se deben calcular gradientes.
# - El modelo se entrenó sin realizar ajustes de hiperparámetros (tasa de aprendizaje, tamaño de batch, número de capas, etc.), lo cual limita su potencial de rendimiento.
# - La representación basada únicamente en tokens y padding puede ser insuficiente para capturar matices semánticos complejos.
#
# #### Áreas de mejora
#
# - Explorar técnicas de optimización de hiperparámetros y regularización para mejorar la capacidad predictiva.
# - Incorporar embeddings preentrenados en español (por ejemplo, FastText o Word2Vec) para enriquecer la representación semántica.
# - Evaluar arquitecturas más modernas como GRU, Transformers o modelos preentrenados que podrían ofrecer un mejor trade-off entre rendimiento y tiempo de cómputo.
#
# #### Valor práctico
#
# - Aunque el rendimiento inicial es bajo, el experimento permite validar el pipeline y sentar bases para futuros ajustes.
# - Este método ofrece un punto de partida funcional para experimentar con arquitecturas más sofisticadas y con un mejor ajuste de hiperparámetros, lo cual podría elevar significativamente la precisión del clasificador.
